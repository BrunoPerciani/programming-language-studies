# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoPerciani/programming-language-studies/blob/main/PI_PR%C3%81TICA_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Atividade realizada pelo discente Bruno Zomignani Perciani (RA: 11202320440) para disciplina de Processamento da Informação (PI) da Universidade Federal do ABC (2024.1), sob a orientação do docente João Marcelo Borovina Josko.*

# %% [markdown]
# # PROBLEMA 01
# Vamos falar sobre a limpeza da sua casa! Eu sei, ninguém gosta muito de fazer, mas não há nada melhor do que estar em uma casa asseada. Pois bem, considerando dois cômodos da sua casa (ou apartamento), qual seria uma lista completa de tarefas de limpeza?

# %% [markdown]
# **SOLUCIONANDO O PROBLEMA 01**

# %%
# PASSO 01: COMPREENDER O PROBLEMA
Queremos uma lista completa de tarefas de limpeza para dois cômodos de uma casa ou apartamento.
- Existem restrições? Sim, precisamos considerar somente dois cômodos da casa.

# %%
# PASSO 02: DECOMPOR O PROBLEMA
- Escolher os dois cômodos que serão limpos.
- Escolher todos os produtos e materiais de limpeza que serão utilizados.
- Limpar o primeiro cômodo escolhido.
- Limpar o segundo cômodo escolhido.
- Mostrar o resultado final da limpeza para posterior inspeção.

# %%
# PASSO 03: PROJETO DE ALGORÍTIMO
-- Entradas
1. Escolher os dois cômodos que serão limpos. (C1 e C2)
2. Escolher todos os produtos e materiais de limpeza que serão utilizados. (Produtos)

-- Processamento
3. Remover o lixo e organizar objetos do primeiro cômodo escolhido.
4. Limpar os móveis e superfícies do primeiro cômodo escolhido.
5. Remover quaisquer tipo de poeira ou sujeira no chão do primeiro cômodo escolhido.
6. Remover o lixo e organizar objetos do segundo cômodo escolhido.
7. Limpar os móveis e superfícies do segundo cômodo escolhido.
8. Remover quaisquer tipo de poeira ou sujeira no chão do primeiro cômodo escolhido.

-- Saídas
9. Mostrar o resultado final da limpeza para posterior inspeção.

# %%
# PASSO 04: IMPLEMENTAÇÃO DO PROGRAMA
Na resolução deste problema não será necessário a implementação do programa.

# %% [markdown]
# # PROBLEMA 02
# A moda é uma importante métrica de tendência central que pode ser aplicada a dados não numéricos (Veja aqui que interessante!) e, ainda, complementar os resultados das métricas co-irmãs média aritmética e mediana. Você consegue criar um algorítmo capaz de identificar a moda? Eu sei que sim.

# %% [markdown]
# **SOLUCIONANDO O PROBLEMA 02**

# %%
# PASSO 01: COMPREENDER O PROBLEMA
Queremos um algorítimo capaz de identificar a moda de dados numéricos e não-numéricos.
- Existem restrições? Não há restrições.

# %%
# PASSO 02: DECOMPOR O PROBLEMA
- Receber conjunto de valores numéricos ou não-numéricos.
- Identificar diferentes valores dentro do conjunto específico.
- Fazer a contagem da recorrência de cada tipo de valor do conjunto.
- Identificar a moda a partir do valor ou valores que ocorrem com mais frequência.
- Apresentar o valor ou valores do conjunto identificados como moda.

# %%
# PASSO 03: PROJETO DE ALGORÍTIMO
-- Entradas
1. Receber conjunto de valores numéricos ou não-numéricos. (Conjunto)

-- Processamento
2. Identificar diferentes valores dentro do conjunto específico.
3. Fazer a contagem da recorrência de cada tipo de valor do conjunto.
4. Identificar a moda a partir do valor ou valores que ocorrem com mais frequência.
5. Se houver empate entre contagem de valores, retornar todos os valores possíveis para moda. (Moda)

-- Saídas
5. Apresentar o valor ou valores do conjunto identificados como moda.

# %%
# PASSO 04: IMPLEMENTAÇÃO DO PROGRAMA
Na resolução deste problema não será necessário a implementação do programa.
